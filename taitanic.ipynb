# %%
import pandas as pd
df_taitanic = pd.read_csv('train.csv')
df_taitanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_taitanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df_taitanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_taitanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_taitanic_male = df_taitanic.query("Sex == 'male'").sort_values(by='Fare', ascending=False)
df_taitanic_male.head(30)
# Out:
#      PassengerId  Survived  Pclass  \
# 679          680         1       1
# 737          738         1       1
# 27            28         0       1
# 438          439         0       1
# 118          119         0       1
# 557          558         0       1
# 527          528         0       1
# 377          378         0       1
# 332          333         0       1
# 305          306         1       1
# 373          374         0       1
# 660          661         1       1
# 802          803         1       1
# 390          391         1       1
# 659          660         0       1
# 550          551         1       1
# 698          699         0       1
# 505          506         0       1
# 544          545         0       1
# 484          485         1       1
# 245          246         0       1
# 224          225         1       1
# 453          454         1       1
# 62            63         0       1
# 34            35         0       1
# ...

# %%
df_taitanic_male[["Age"]][25:45]
# Out:
#      Age
# 50   7.0
# 51  21.0
# 54  65.0
# 55   NaN
# 57  28.5
# 59  11.0
# 60  22.0
# 62  45.0
# 63   4.0
# 64   NaN
# 65   NaN
# 67  19.0
# 69  26.0
# 70  32.0
# 72  21.0
# 73  26.0
# 74  32.0
# 75  25.0
# 76   NaN
# 77   NaN

# %%
df_taitanic_male[df_taitanic_male["Age"] > 25].sort_values(by='PassengerId')
# Out:
#      PassengerId  Survived  Pclass                           Name   Sex   Age  \
# 4              5         0       3       Allen, Mr. William Henry  male  35.0
# 6              7         0       1        McCarthy, Mr. Timothy J  male  54.0
# 13            14         0       3    Andersson, Mr. Anders Johan  male  39.0
# 20            21         0       2           Fynney, Mr. Joseph J  male  35.0
# 21            22         1       2          Beesley, Mr. Lawrence  male  34.0
# ..           ...       ...     ...                            ...   ...   ...
# 881          882         0       3             Markun, Mr. Johann  male  33.0
# 883          884         0       2  Banfield, Mr. Frederick James  male  28.0
# 886          887         0       2          Montvila, Rev. Juozas  male  27.0
# 889          890         1       1          Behr, Mr. Karl Howell  male  26.0
# 890          891         0       3            Dooley, Mr. Patrick  male  32.0
#
# ...

# %%
df_taitanic_male.sort_values(by = ['Age', 'Fare'], ascending = [True, False])
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 803          804         1       3   Thomas, Master. Assad Alexander  male
# 755          756         1       2         Hamalainen, Master. Viljo  male
# 78            79         1       2     Caldwell, Master. Alden Gates  male
# 831          832         1       2   Richards, Master. George Sibley  male
# 305          306         1       1    Allison, Master. Hudson Trevor  male
# ..           ...       ...     ...                               ...   ...
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# 732          733         0       2              Knight, Mr. Robert J  male
# 815          816         0       1                  Fry, Mr. Richard  male
#
#       Age  SibSp  Parch  Ticket      Fare    Cabin Embarked
# ...

# %%
df_taitanic_male.sort_values(by = "Age", ascending = False,axis=0) # axis = 0は列
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 116          117         0       3                  Connors, Mr. Patrick
# ..           ...       ...     ...                                   ...
# 839          840         1       1                  Marechal, Mr. Pierre
# 846          847         0       3              Sage, Mr. Douglas Bullen
# 859          860         0       3                      Razi, Mr. Raihed
# 868          869         0       3           van Melkebeke, Mr. Philemon
# 878          879         0       3                    Laleff, Mr. Kristo
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# ...

# %%
df_taitanic_male.sort_values(by  ="Fare", ascending = False, axis = 0)
# Out:
#      PassengerId  Survived  Pclass                                Name   Sex  \
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez  male
# 737          738         1       1              Lesurer, Mr. Gustave J  male
# 27            28         0       1      Fortune, Mr. Charles Alexander  male
# 438          439         0       1                   Fortune, Mr. Mark  male
# 118          119         0       1            Baxter, Mr. Quigg Edmond  male
# ..           ...       ...     ...                                 ...   ...
# 263          264         0       1               Harrison, Mr. William  male
# 271          272         1       3        Tornquist, Mr. William Henry  male
# 822          823         0       1     Reuchlin, Jonkheer. John George  male
# 277          278         0       2         Parkes, Mr. Francis "Frank"  male
# 732          733         0       2                Knight, Mr. Robert J  male
#
# ...

# %%
df_taitanic_male.sort_index(axis  =1,ascending = False)
# Out:
#                Ticket  Survived  SibSp   Sex  Pclass  PassengerId  Parch  \
# 0           A/5 21171         0      1  male       3            1      0
# 4              373450         0      0  male       3            5      0
# 5              330877         0      0  male       3            6      0
# 6               17463         0      0  male       1            7      0
# 7              349909         0      3  male       3            8      1
# ..                ...       ...    ...   ...     ...          ...    ...
# 883  C.A./SOTON 34068         0      0  male       2          884      0
# 884   SOTON/OQ 392076         0      0  male       3          885      0
# 886            211536         0      0  male       2          887      0
# 889            111369         1      0  male       1          890      0
# 890            370376         0      0  male       3          891      0
#
#                                Name     Fare Embarked Cabin   Age
# ...

# %%
df_taitanic_male.groupby("Name").sum().sort_values(by = "Age", ascending = False)
# Out:
#                                       PassengerId  Survived  Pclass   Sex  \
# Name
# Barkworth, Mr. Algernon Henry Wilson          631         1       1  male
# Svensson, Mr. Johan                           852         0       3  male
# Artagaveytia, Mr. Ramon                       494         0       1  male
# Goldschmidt, Mr. George B                      97         0       1  male
# Connors, Mr. Patrick                          117         0       3  male
# ...                                           ...       ...     ...   ...
# O'Brien, Mr. Timothy                          553         0       3  male
# O'Connell, Mr. Patrick D                      630         0       3  male
# O'Connor, Mr. Maurice                         460         0       3  male
# Olsen, Mr. Ole Martin                         155         0       3  male
# van Melkebeke, Mr. Philemon                   869         0       3  male
#
# ...

# %%
df_taitanic_pivot = df_taitanic_male.pivot_table(index = "PassengerId",columns="Name",values="Survived")
df_taitanic_pivot
# Out:
# Name         Abbing, Mr. Anthony  Abbott, Mr. Rossmore Edward  \
# PassengerId
# 1                            NaN                          NaN
# 5                            NaN                          NaN
# 6                            NaN                          NaN
# 7                            NaN                          NaN
# 8                            NaN                          NaN
# ...                          ...                          ...
# 884                          NaN                          NaN
# 885                          NaN                          NaN
# 887                          NaN                          NaN
# 890                          NaN                          NaN
# 891                          NaN                          NaN
#
# Name         Abelson, Mr. Samuel  Adahl, Mr. Mauritz Nils Martin  \
# PassengerId
# 1                            NaN                             NaN
# ...

# %%
pivot_table = df_taitanic_male.pivot_table(values='Survived', index='Pclass', columns='Sex', aggfunc='mean')
pivot_table
# Out:
# Sex         male
# Pclass
# 1       0.368852
# 2       0.157407
# 3       0.135447

# %%
df_taitanic_female_survived = df_taitanic.query("Sex == 'female'").sort_values(by='Fare', ascending=False)
df_taitanic_female_survived.head(30)
# Out:
#      PassengerId  Survived  Pclass  \
# 258          259         1       1
# 341          342         1       1
# 88            89         1       1
# 742          743         1       1
# 311          312         1       1
# 299          300         1       1
# 716          717         1       1
# 380          381         1       1
# 700          701         1       1
# 730          731         1       1
# 779          780         1       1
# 689          690         1       1
# 856          857         1       1
# 318          319         1       1
# 609          610         1       1
# 268          269         1       1
# 708          709         1       1
# 297          298         0       1
# 498          499         0       1
# 31            32         1       1
# 195          196         1       1
# 325          326         1       1
# 269          270         1       1
# 337          338         1       1
# 319          320         1       1
# ...
